# %%
from datasets import load_dataset
import pandas as pd

from collections import defaultdict 
from tqdm import tqdm


dataset = load_dataset("conll2003")
# Out:
# Reusing dataset conll2003 (C:\Users\Yang Li\.cache\huggingface\datasets\conll2003\conll2003\1.0.0\63ba56944e35c1943434322a07ceefd79864672041b7834583709af4a5de4664)

# %%
from transformers import pipeline

nlp = pipeline("ner",device = 0, grouped_entities=True)

# %%
def bert_pipeline(lst):
    seq = " ".join(lst)
    return nlp(seq)

# %%
df = pd.DataFrame(dataset['train'])
df['sentence_length'] = df.tokens.apply(lambda x: len(x))
result = []

# %%
for i in tqdm(list(df.tokens)):
    result.append(bert_pipeline(i))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 14041/14041 [07:01<00:00, 33.33it/s]

# %%
ner_tag = ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC', 'B-MISC', 'I-MISC']

# %%
bert_pipeline(dataset['train']['tokens'][2])
# Out:
# [{'entity_group': 'LOC',
#   'score': 0.9967032372951508,
#   'word': 'BRUSSELS',
#   'start': 0,
#   'end': 8}]

# %%
for _ in ner_tag:
    temp_stats = defaultdict(int)
    for index, value in enumerate(result):

# %%
result[]
# Out:
# [[{'entity_group': 'ORG',
#    'score': 0.9985100030899048,
#    'word': 'EU',
#    'start': 0,
#    'end': 2},
#   {'entity_group': 'MISC',
#    'score': 0.9991999268531799,
#    'word': 'German',
#    'start': 11,
#    'end': 17},
#   {'entity_group': 'MISC',
#    'score': 0.9993912577629089,
#    'word': 'British',
#    'start': 34,
#    'end': 41}],
#  [{'entity_group': 'PER',
#    'score': 0.9996874928474426,
#    'word': 'Peter Blackburn',
#    'start': 0,
#    'end': 15}],
#  [{'entity_group': 'LOC',
#    'score': 0.9967032372951508,
#    'word': 'BRUSSELS',
#    'start': 0,
#    'end': 8}],
#  [{'entity_group': 'ORG',
#    'score': 0.9990918040275574,
#    'word': 'European Commission',
#    'start': 4,
#    'end': 23},
#   {'entity_group': 'MISC',
#    'score': 0.9992934465408325,
#    'word': 'German',
#    'start': 59,
#    'end': 65},
#   {'entity_group': 'MISC',
#    'score': 0.9993801712989807,
#    'word': 'British',
#    'start': 94,
#    'end': 101}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998177886009216,
#    'word': 'Germany',
#    'start': 0,
#    'end': 7},
#   {'entity_group': 'ORG',
#    'score': 0.9992266893386841,
#    'word': 'European Union',
#    'start': 33,
#    'end': 47},
#   {'entity_group': 'PER',
#    'score': 0.995104193687439,
#    'word': 'Werner Zwingmann',
#    'start': 72,
#    'end': 88},
#   {'entity_group': 'LOC',
#    'score': 0.9997745156288147,
#    'word': 'Britain',
#    'start': 164,
#    'end': 171}],
#  [{'entity_group': 'ORG',
#    'score': 0.9985644221305847,
#    'word': 'Commission',
#    'start': 93,
#    'end': 103},
#   {'entity_group': 'PER',
#    'score': 0.9956981440385183,
#    'word': 'Nikolaus van der Pas',
#    'start': 123,
#    'end': 143}],
#  [{'entity_group': 'ORG',
#    'score': 0.9994260668754578,
#    'word': 'European Union',
#    'start': 115,
#    'end': 129}],
#  [{'entity_group': 'ORG',
#    'score': 0.9972980618476868,
#    'word': 'EU',
#    'start': 33,
#    'end': 35},
#   {'entity_group': 'PER',
#    'score': 0.997237354516983,
#    'word': 'Franz Fischler',
#    'start': 54,
#    'end': 68}],
#  [{'entity_group': 'PER',
#    'score': 0.9812296430269877,
#    'word': 'Fischler',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'MISC',
#    'score': 0.9975109696388245,
#    'word': 'EU',
#    'start': 18,
#    'end': 20},
#   {'entity_group': 'LOC',
#    'score': 0.999863862991333,
#    'word': 'Britain',
#    'start': 54,
#    'end': 61},
#   {'entity_group': 'LOC',
#    'score': 0.9998654723167419,
#    'word': 'France',
#    'start': 66,
#    'end': 72},
#   {'entity_group': 'MISC',
#    'score': 0.975109393397967,
#    'word': 'Bovine Spongiform Encephalopathy',
#    'start': 127,
#    'end': 159},
#   {'entity_group': 'MISC',
#    'score': 0.9976144433021545,
#    'word': 'BSE',
#    'start': 162,
#    'end': 165}],
#  [{'entity_group': 'PER',
#    'score': 0.992094616095225,
#    'word': 'Fischler',
#    'start': 4,
#    'end': 12},
#   {'entity_group': 'ORG',
#    'score': 0.9988690614700317,
#    'word': 'EU',
#    'start': 53,
#    'end': 55}],
#  [{'entity_group': 'MISC',
#    'score': 0.9971497058868408,
#    'word': 'Spanish',
#    'start': 0,
#    'end': 7},
#   {'entity_group': 'PER',
#    'score': 0.9860043168067932,
#    'word': 'Loyola de Palacio',
#    'start': 22,
#    'end': 39},
#   {'entity_group': 'PER',
#    'score': 0.9882398049036661,
#    'word': 'Fischler',
#    'start': 60,
#    'end': 68},
#   {'entity_group': 'ORG',
#    'score': 0.997645378112793,
#    'word': 'EU',
#    'start': 75,
#    'end': 77}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.9998134970664978,
#    'word': 'France',
#    'start': 5,
#    'end': 11},
#   {'entity_group': 'LOC',
#    'score': 0.9997223615646362,
#    'word': 'Britain',
#    'start': 16,
#    'end': 23},
#   {'entity_group': 'PER',
#    'score': 0.989815870920817,
#    'word': 'Fischler',
#    'start': 31,
#    'end': 39}],
#  [{'entity_group': 'ORG',
#    'score': 0.9992572665214539,
#    'word': 'EU',
#    'start': 4,
#    'end': 6}],
#  [{'entity_group': 'MISC',
#    'score': 0.9979804754257202,
#    'word': 'BSE',
#    'start': 84,
#    'end': 87}],
#  [{'entity_group': 'MISC',
#    'score': 0.9991274476051331,
#    'word': 'British',
#    'start': 0,
#    'end': 7},
#   {'entity_group': 'MISC',
#    'score': 0.999220073223114,
#    'word': 'German',
#    'start': 118,
#    'end': 124},
#   {'entity_group': 'MISC',
#    'score': 0.9993876218795776,
#    'word': 'British',
#    'start': 165,
#    'end': 172},
#   {'entity_group': 'LOC',
#    'score': 0.9995108246803284,
#    'word': 'Europe',
#    'start': 211,
#    'end': 217}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997950196266174,
#    'word': 'Germany',
#    'start': 83,
#    'end': 90},
#   {'entity_group': 'ORG',
#    'score': 0.9989930629730225,
#    'word': "Welsh National Farmers'Union",
#    'start': 103,
#    'end': 133},
#   {'entity_group': 'ORG',
#    'score': 0.9989805817604065,
#    'word': 'NFU',
#    'start': 136,
#    'end': 139},
#   {'entity_group': 'PER',
#    'score': 0.9994773070017496,
#    'word': 'John Lloyd Jones',
#    'start': 151,
#    'end': 167},
#   {'entity_group': 'ORG',
#    'score': 0.9602051973342896,
#    'word': 'BBC radio',
#    'start': 176,
#    'end': 185}],
#  [{'entity_group': 'LOC',
#    'score': 0.9992501139640808,
#    'word': 'Bonn',
#    'start': 0,
#    'end': 4},
#   {'entity_group': 'MISC',
#    'score': 0.9994039535522461,
#    'word': 'British',
#    'start': 99,
#    'end': 106}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998239278793335,
#    'word': 'Germany',
#    'start': 0,
#    'end': 7},
#   {'entity_group': 'LOC',
#    'score': 0.9998703598976135,
#    'word': 'Britain',
#    'start': 35,
#    'end': 42}],
#  [{'entity_group': 'MISC',
#    'score': 0.9995167851448059,
#    'word': 'British',
#    'start': 30,
#    'end': 37}],
#  [{'entity_group': 'PER',
#    'score': 0.9987602829933167,
#    'word': 'Hendrix',
#    'start': 5,
#    'end': 12}],
#  [{'entity_group': 'LOC',
#    'score': 0.9969093650579453,
#    'word': 'LONDON',
#    'start': 0,
#    'end': 6}],
#  [{'entity_group': 'LOC',
#    'score': 0.9992403388023376,
#    'word': 'U',
#    'start': 44,
#    'end': 45},
#   {'entity_group': 'LOC',
#    'score': 0.8217426240444183,
#    'word': 'S.',
#    'start': 46,
#    'end': 48},
#   {'entity_group': 'PER',
#    'score': 0.9992041985193888,
#    'word': 'Jimi Hendrix',
#    'start': 63,
#    'end': 75}],
#  [{'entity_group': 'LOC',
#    'score': 0.9996633529663086,
#    'word': 'Florida',
#    'start': 2,
#    'end': 9},
#   {'entity_group': 'MISC',
#    'score': 0.9895176192124685,
#    'word': "Ain't no telling",
#    'start': 72,
#    'end': 89},
#   {'entity_group': 'PER',
#    'score': 0.9991937875747681,
#    'word': 'Hendrix',
#    'start': 100,
#    'end': 107},
#   {'entity_group': 'LOC',
#    'score': 0.9991096258163452,
#    'word': 'London',
#    'start': 129,
#    'end': 135}],
#  [{'entity_group': 'MISC',
#    'score': 0.9991498589515686,
#    'word': 'English',
#    'start': 44,
#    'end': 51},
#   {'entity_group': 'LOC',
#    'score': 0.9990639686584473,
#    'word': 'Nottingham',
#    'start': 60,
#    'end': 70}],
#  [{'entity_group': 'PER',
#    'score': 0.9995296001434326,
#    'word': 'Hendrix',
#    'start': 70,
#    'end': 77},
#   {'entity_group': 'PER',
#    'score': 0.9864354431629181,
#    'word': 'Kathy Etchingham',
#    'start': 99,
#    'end': 115}],
#  [{'entity_group': 'PER',
#    'score': 0.9994182586669922,
#    'word': 'Hendrix',
#    'start': 69,
#    'end': 76},
#   {'entity_group': 'MISC',
#    'score': 0.9992144107818604,
#    'word': 'Australian',
#    'start': 117,
#    'end': 127}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.9997981190681458,
#    'word': 'China',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'LOC',
#    'score': 0.9997932314872742,
#    'word': 'Taiwan',
#    'start': 11,
#    'end': 17}],
#  [{'entity_group': 'LOC',
#    'score': 0.9922555238008499,
#    'word': 'BEIJING',
#    'start': 0,
#    'end': 7}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998232126235962,
#    'word': 'China',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'LOC',
#    'score': 0.9997332096099854,
#    'word': 'Taipei',
#    'start': 26,
#    'end': 32},
#   {'entity_group': 'LOC',
#    'score': 0.9984829127788544,
#    'word': 'Taiwan Strait',
#    'start': 97,
#    'end': 110},
#   {'entity_group': 'LOC',
#    'score': 0.9998248815536499,
#    'word': 'Ukraine',
#    'start': 127,
#    'end': 134},
#   {'entity_group': 'MISC',
#    'score': 0.9986293911933899,
#    'word': 'Taiwanese',
#    'start': 138,
#    'end': 147},
#   {'entity_group': 'PER',
#    'score': 0.9989102681477865,
#    'word': 'Lien Chan',
#    'start': 163,
#    'end': 172},
#   {'entity_group': 'LOC',
#    'score': 0.9995759129524231,
#    'word': 'Beijing',
#    'start': 199,
#    'end': 206}],
#  [{'entity_group': 'MISC',
#    'score': 0.9988463521003723,
#    'word': 'Chinese',
#    'start': 26,
#    'end': 33},
#   {'entity_group': 'LOC',
#    'score': 0.999803364276886,
#    'word': 'Taiwan',
#    'start': 104,
#    'end': 110},
#   {'entity_group': 'ORG',
#    'score': 0.9951176643371582,
#    'word': 'Foreign Ministry',
#    'start': 113,
#    'end': 129},
#   {'entity_group': 'PER',
#    'score': 0.9953143000602722,
#    'word': 'Shen Guo',
#    'start': 140,
#    'end': 148},
#   {'entity_group': 'PER',
#    'score': 0.8338767290115356,
#    'word': '##g',
#    'start': 151,
#    'end': 152},
#   {'entity_group': 'ORG',
#    'score': 0.9980975985527039,
#    'word': 'Reuters',
#    'start': 158,
#    'end': 165},
#   {'entity_group': 'LOC',
#    'score': 0.9997302293777466,
#    'word': 'Taiwan',
#    'start': 250,
#    'end': 256}],
#  [{'entity_group': 'LOC',
#    'score': 0.999803900718689,
#    'word': 'China',
#    'start': 19,
#    'end': 24},
#   {'entity_group': 'LOC',
#    'score': 0.9998050332069397,
#    'word': 'Taipei',
#    'start': 48,
#    'end': 54},
#   {'entity_group': 'PER',
#    'score': 0.9914626677831014,
#    'word': 'Tang Shubei',
#    'start': 57,
#    'end': 68},
#   {'entity_group': 'LOC',
#    'score': 0.9998654127120972,
#    'word': 'Taiwan',
#    'start': 104,
#    'end': 110}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.999688521027565,
#    'word': "People's Daily",
#    'start': 78,
#    'end': 93},
#   {'entity_group': 'PER',
#    'score': 0.995400607585907,
#    'word': 'Tang',
#    'start': 101,
#    'end': 105}],
#  [{'entity_group': 'ORG',
#    'score': 0.5163016319274902,
#    'word': 'Shen',
#    'start': 24,
#    'end': 28},
#   {'entity_group': 'ORG',
#    'score': 0.9976950685183207,
#    'word': 'Reuters Television',
#    'start': 34,
#    'end': 52},
#   {'entity_group': 'PER',
#    'score': 0.9919196367263794,
#    'word': 'Tang',
#    'start': 92,
#    'end': 96},
#   {'entity_group': 'LOC',
#    'score': 0.9997540712356567,
#    'word': 'Taiwan',
#    'start': 196,
#    'end': 202},
#   {'entity_group': 'LOC',
#    'score': 0.9996799230575562,
#    'word': 'Beijing',
#    'start': 211,
#    'end': 218}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998231530189514,
#    'word': 'China',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'LOC',
#    'score': 0.9996121525764465,
#    'word': 'Taipei',
#    'start': 35,
#    'end': 41},
#   {'entity_group': 'LOC',
#    'score': 0.9998549818992615,
#    'word': 'Ukraine',
#    'start': 123,
#    'end': 130},
#   {'entity_group': 'MISC',
#    'score': 0.9987552165985107,
#    'word': 'Taiwanese',
#    'start': 144,
#    'end': 153},
#   {'entity_group': 'PER',
#    'score': 0.9949871897697449,
#    'word': 'Lien',
#    'start': 169,
#    'end': 173}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997748732566833,
#    'word': 'China',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'LOC',
#    'score': 0.9997153282165527,
#    'word': 'Taiwan',
#    'start': 26,
#    'end': 32}],
#  [{'entity_group': 'LOC',
#    'score': 0.9922555238008499,
#    'word': 'BEIJING',
#    'start': 0,
#    'end': 7}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998317360877991,
#    'word': 'China',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'LOC',
#    'score': 0.9997756481170654,
#    'word': 'Taiwan',
#    'start': 52,
#    'end': 58}],
#  [{'entity_group': 'ORG',
#    'score': 0.9974641601244608,
#    'word': 'Xinhua',
#    'start': 84,
#    'end': 90},
#   {'entity_group': 'PER',
#    'score': 0.9768144885698954,
#    'word': 'Tang Shubei',
#    'start': 110,
#    'end': 121},
#   {'entity_group': 'ORG',
#    'score': 0.9992729851177761,
#    'word': 'Association for Relations Across the Taiwan Straits',
#    'start': 155,
#    'end': 206}],
#  [{'entity_group': 'MISC',
#    'score': 0.9991057515144348,
#    'word': 'German',
#    'start': 0,
#    'end': 6}],
#  [{'entity_group': 'LOC',
#    'score': 0.996057254927499,
#    'word': 'FRANKFURT',
#    'start': 0,
#    'end': 9}],
#  [{'entity_group': 'MISC',
#    'score': 0.9992170333862305,
#    'word': 'German',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'ORG',
#    'score': 0.9821730256080627,
#    'word': 'Federal office for motor vehicles',
#    'start': 123,
#    'end': 156}],
#  [],
#  [],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.9987867474555969,
#    'word': 'Germans',
#    'start': 52,
#    'end': 59},
#   {'entity_group': 'MISC',
#    'score': 0.9994332790374756,
#    'word': 'German',
#    'start': 67,
#    'end': 73}],
#  [{'entity_group': 'MISC',
#    'score': 0.9993297457695007,
#    'word': 'German',
#    'start': 11,
#    'end': 17}],
#  [{'entity_group': 'ORG',
#    'score': 0.999604731798172,
#    'word': 'Volkswagen AG',
#    'start': 0,
#    'end': 13}],
#  [{'entity_group': 'ORG',
#    'score': 0.9997114340464274,
#    'word': 'Opel AG',
#    'start': 0,
#    'end': 7},
#   {'entity_group': 'ORG',
#    'score': 0.9997318983078003,
#    'word': 'General Motors',
#    'start': 22,
#    'end': 36}],
#  [{'entity_group': 'ORG',
#    'score': 0.9994433522224426,
#    'word': 'Ford',
#    'start': 10,
#    'end': 14}],
#  [{'entity_group': 'ORG',
#    'score': 0.9981014430522919,
#    'word': 'Seat',
#    'start': 5,
#    'end': 9},
#   {'entity_group': 'ORG',
#    'score': 0.9985224008560181,
#    'word': 'Porsche',
#    'start': 14,
#    'end': 21}],
#  [{'entity_group': 'ORG',
#    'score': 0.9960741996765137,
#    'word': 'Seat',
#    'start': 0,
#    'end': 4}],
#  [{'entity_group': 'ORG',
#    'score': 0.9971223473548889,
#    'word': 'Porsche',
#    'start': 0,
#    'end': 7}],
#  [{'entity_group': 'MISC',
#    'score': 0.9410489946603775,
#    'word': 'GREEK',
#    'start': 0,
#    'end': 5}],
#  [{'entity_group': 'LOC',
#    'score': 0.992986723780632,
#    'word': 'ATHENS',
#    'start': 0,
#    'end': 6}],
#  [{'entity_group': 'MISC',
#    'score': 0.9988602995872498,
#    'word': 'Greek',
#    'start': 4,
#    'end': 9},
#   {'entity_group': 'PER',
#    'score': 0.9977397322654724,
#    'word': 'Costas Simitis',
#    'start': 85,
#    'end': 99},
#   {'entity_group': 'PER',
#    'score': 0.9884550486292157,
#    'word': 'Costas Skandalidis',
#    'start': 147,
#    'end': 165}],
#  [{'entity_group': 'PER',
#    'score': 0.9974746346473694,
#    'word': 'Costas Simitis',
#    'start': 15,
#    'end': 29},
#   {'entity_group': 'PER',
#    'score': 0.9701986670494079,
#    'word': 'Skandalidis',
#    'start': 121,
#    'end': 132}],
#  [{'entity_group': 'PER',
#    'score': 0.9901502898761204,
#    'word': 'Dimitris Kontogiannis',
#    'start': 3,
#    'end': 24},
#   {'entity_group': 'ORG',
#    'score': 0.9993886351585388,
#    'word': 'Athens Newsroom',
#    'start': 27,
#    'end': 42}],
#  [{'entity_group': 'ORG',
#    'score': 0.9991165399551392,
#    'word': 'BayerVB',
#    'start': 0,
#    'end': 7},
#   {'entity_group': 'MISC',
#    'score': 0.9988093376159668,
#    'word': 'C',
#    'start': 13,
#    'end': 14}],
#  [{'entity_group': 'LOC',
#    'score': 0.9969093650579453,
#    'word': 'LONDON',
#    'start': 0,
#    'end': 6}],
#  [{'entity_group': 'PER',
#    'score': 0.9983422458171844,
#    'word': 'Toronto Dominion',
#    'start': 49,
#    'end': 65}],
#  [{'entity_group': 'ORG',
#    'score': 0.8970683634281158,
#    'word': 'BAYERISCHE VEREINS',
#    'start': 9,
#    'end': 27},
#   {'entity_group': 'LOC',
#    'score': 0.5204050540924072,
#    'word': '##BA',
#    'start': 27,
#    'end': 29},
#   {'entity_group': 'ORG',
#    'score': 0.6491065621376038,
#    'word': '##K',
#    'start': 30,
#    'end': 31}],
#  [{'entity_group': 'MISC',
#    'score': 0.9985091090202332,
#    'word': 'C',
#    'start': 4,
#    'end': 5}],
#  [],
#  [],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.997708261013031,
#    'word': 'S & P',
#    'start': 0,
#    'end': 3},
#   {'entity_group': 'LOC',
#    'score': 0.9955045580863953,
#    'word': 'US',
#    'start': 40,
#    'end': 42},
#   {'entity_group': 'LOC',
#    'score': 0.99951171875,
#    'word': 'UK',
#    'start': 45,
#    'end': 47},
#   {'entity_group': 'LOC',
#    'score': 0.998565137386322,
#    'word': 'CA',
#    'start': 50,
#    'end': 52}],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.789008766412735,
#    'word': 'GERMAN',
#    'start': 8,
#    'end': 14}],
#  [],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.8161884979768232,
#    'word': 'BAYERISCHE VEREINSBA',
#    'start': 6,
#    'end': 26},
#   {'entity_group': 'ORG',
#    'score': 0.8401135206222534,
#    'word': '##K',
#    'start': 27,
#    'end': 28}],
#  [{'entity_group': 'ORG',
#    'score': 0.9996681213378906,
#    'word': 'London Newsroom',
#    'start': 3,
#    'end': 18}],
#  [{'entity_group': 'ORG',
#    'score': 0.9858747522036234,
#    'word': 'Venantius',
#    'start': 0,
#    'end': 9}],
#  [{'entity_group': 'LOC',
#    'score': 0.9969093650579453,
#    'word': 'LONDON',
#    'start': 0,
#    'end': 6}],
#  [{'entity_group': 'ORG',
#    'score': 0.9992339164018631,
#    'word': 'Lehman Brothers International',
#    'start': 64,
#    'end': 93}],
#  [{'entity_group': 'ORG',
#    'score': 0.9884266555309296,
#    'word': 'VENANTIUS AB',
#    'start': 9,
#    'end': 21},
#   {'entity_group': 'MISC',
#    'score': 0.7897506058216095,
#    'word': 'SWEDIS',
#    'start': 24,
#    'end': 30}],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.5743643641471863,
#    'word': '3',
#    'start': 14,
#    'end': 15}],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.9985869924227396,
#    'word': 'S & P',
#    'start': 5,
#    'end': 8}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.7633750736713409,
#    'word': 'LON',
#    'start': 8,
#    'end': 11},
#   {'entity_group': 'MISC',
#    'score': 0.7094244956970215,
#    'word': '##DON',
#    'start': 11,
#    'end': 14},
#   {'entity_group': 'LOC',
#    'score': 0.9956231713294983,
#    'word': 'US',
#    'start': 49,
#    'end': 51},
#   {'entity_group': 'LOC',
#    'score': 0.9996042251586914,
#    'word': 'UK',
#    'start': 54,
#    'end': 56},
#   {'entity_group': 'LOC',
#    'score': 0.998341977596283,
#    'word': 'JP',
#    'start': 59,
#    'end': 61},
#   {'entity_group': 'LOC',
#    'score': 0.9821953475475311,
#    'word': 'FR',
#    'start': 64,
#    'end': 66}],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.7857524380087852,
#    'word': 'ENGLIS',
#    'start': 8,
#    'end': 14},
#   {'entity_group': 'PER',
#    'score': 0.43069761991500854,
#    'word': 'S',
#    'start': 26,
#    'end': 27}],
#  [],
#  [],
#  [{'entity_group': 'ORG',
#    'score': 0.9996742208798727,
#    'word': 'London Newsroom',
#    'start': 3,
#    'end': 18}],
#  [{'entity_group': 'LOC',
#    'score': 0.9994267225265503,
#    'word': 'Syria',
#    'start': 25,
#    'end': 30},
#   {'entity_group': 'ORG',
#    'score': 0.9991079767545065,
#    'word': 'Lloyds Shipping',
#    'start': 33,
#    'end': 48}],
#  [{'entity_group': 'ORG',
#    'score': 0.9993020057678222,
#    'word': 'Lloyds Shipping Intelligence Service',
#    'start': 21,
#    'end': 57}],
#  [{'entity_group': 'LOC',
#    'score': 0.9946516990661621,
#    'word': 'LATTAKIA',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'LOC',
#    'score': 0.9906652420759201,
#    'word': 'Lattakia',
#    'start': 36,
#    'end': 44},
#   {'entity_group': 'LOC',
#    'score': 0.9870345989863077,
#    'word': 'Tartous',
#    'start': 49,
#    'end': 56}],
#  [{'entity_group': 'LOC',
#    'score': 0.999783992767334,
#    'word': 'Israel',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'LOC',
#    'score': 0.9998524785041809,
#    'word': 'Syria',
#    'start': 36,
#    'end': 41}],
#  [{'entity_group': 'PER',
#    'score': 0.9983975291252136,
#    'word': 'Colleen Siegel',
#    'start': 0,
#    'end': 14}],
#  [{'entity_group': 'LOC',
#    'score': 0.9935106635093689,
#    'word': 'JERUSALEM',
#    'start': 0,
#    'end': 9}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998025894165039,
#    'word': 'Israel',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'LOC',
#    'score': 0.999865710735321,
#    'word': 'Syria',
#    'start': 41,
#    'end': 46}],
#  [{'entity_group': 'PER',
#    'score': 0.9967365562915802,
#    'word': 'Itamar Rabinovich',
#    'start': 0,
#    'end': 17},
#   {'entity_group': 'LOC',
#    'score': 0.9996899366378784,
#    'word': 'Israel',
#    'start': 27,
#    'end': 33},
#   {'entity_group': 'LOC',
#    'score': 0.9993578195571899,
#    'word': 'Washington',
#    'start': 51,
#    'end': 61},
#   {'entity_group': 'LOC',
#    'score': 0.9998377561569214,
#    'word': 'Syria',
#    'start': 101,
#    'end': 106},
#   {'entity_group': 'ORG',
#    'score': 0.9970279932022095,
#    'word': 'Israel Radio',
#    'start': 114,
#    'end': 126},
#   {'entity_group': 'LOC',
#    'score': 0.9995276927947998,
#    'word': 'Damascus',
#    'start': 142,
#    'end': 150}],
#  [{'entity_group': 'MISC',
#    'score': 0.9989443421363831,
#    'word': 'Syrian',
#    'start': 23,
#    'end': 29}],
#  [{'entity_group': 'MISC',
#    'score': 0.9973692297935486,
#    'word': 'Syrian',
#    'start': 4,
#    'end': 10},
#   {'entity_group': 'LOC',
#    'score': 0.9988370537757874,
#    'word': 'Washington',
#    'start': 90,
#    'end': 100}],
#  [{'entity_group': 'PER',
#    'score': 0.9804347356160482,
#    'word': 'Rabinovich',
#    'start': 0,
#    'end': 10}],
#  [{'entity_group': 'PER',
#    'score': 0.996085388319833,
#    'word': 'Eliahu Ben - Elissar',
#    'start': 23,
#    'end': 41},
#   {'entity_group': 'MISC',
#    'score': 0.9988967776298523,
#    'word': 'Israeli',
#    'start': 53,
#    'end': 60},
#   {'entity_group': 'LOC',
#    'score': 0.9998390078544617,
#    'word': 'Egypt',
#    'start': 70,
#    'end': 75},
#   {'entity_group': 'ORG',
#    'score': 0.8816938996315002,
#    'word': 'Likud',
#    'start': 91,
#    'end': 96}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997727274894714,
#    'word': 'Israel',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'LOC',
#    'score': 0.9998186230659485,
#    'word': 'Syria',
#    'start': 25,
#    'end': 30},
#   {'entity_group': 'LOC',
#    'score': 0.9992753267288208,
#    'word': 'Washington',
#    'start': 47,
#    'end': 57}],
#  [{'entity_group': 'LOC',
#    'score': 0.9996355772018433,
#    'word': 'Damascus',
#    'start': 15,
#    'end': 23}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998261332511902,
#    'word': 'Syria',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'LOC',
#    'score': 0.9997706413269043,
#    'word': 'Israel',
#    'start': 14,
#    'end': 20},
#   {'entity_group': 'MISC',
#    'score': 0.9984240531921387,
#    'word': 'Israeli',
#    'start': 86,
#    'end': 93},
#   {'entity_group': 'LOC',
#    'score': 0.999708890914917,
#    'word': 'Damascus',
#    'start': 119,
#    'end': 127}],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.9987165331840515,
#    'word': 'Syrian',
#    'start': 32,
#    'end': 38},
#   {'entity_group': 'PER',
#    'score': 0.9958074688911438,
#    'word': 'Hafez al',
#    'start': 49,
#    'end': 57},
#   {'entity_group': 'PER',
#    'score': 0.9955357909202576,
#    'word': 'Assad',
#    'start': 61,
#    'end': 66},
#   {'entity_group': 'LOC',
#    'score': 0.9996045827865601,
#    'word': 'Israel',
#    'start': 75,
#    'end': 81},
#   {'entity_group': 'MISC',
#    'score': 0.9988830089569092,
#    'word': 'Israeli',
#    'start': 157,
#    'end': 164},
#   {'entity_group': 'PER',
#    'score': 0.9996640682220459,
#    'word': 'David Levy',
#    'start': 182,
#    'end': 192},
#   {'entity_group': 'ORG',
#    'score': 0.9977056980133057,
#    'word': 'Israel Radio',
#    'start': 198,
#    'end': 210}],
#  [{'entity_group': 'MISC',
#    'score': 0.9989917278289795,
#    'word': 'Israeli',
#    'start': 26,
#    'end': 33},
#   {'entity_group': 'PER',
#    'score': 0.9828917384147644,
#    'word': 'Benjamin Netanyahu',
#    'start': 49,
#    'end': 67},
#   {'entity_group': 'LOC',
#    'score': 0.9697713255882263,
#    'word': 'Golan Heights Israel',
#    'start': 109,
#    'end': 129},
#   {'entity_group': 'LOC',
#    'score': 0.999822199344635,
#    'word': 'Syria',
#    'start': 144,
#    'end': 149},
#   {'entity_group': 'LOC',
#    'score': 0.9992972612380981,
#    'word': 'Middle East',
#    'start': 162,
#    'end': 173}],
#  [{'entity_group': 'MISC',
#    'score': 0.9978713393211365,
#    'word': 'Israeli',
#    'start': 0,
#    'end': 7},
#   {'entity_group': 'MISC',
#    'score': 0.9986415505409241,
#    'word': 'Syrian',
#    'start': 8,
#    'end': 14},
#   {'entity_group': 'LOC',
#    'score': 0.9989822208881378,
#    'word': 'Golan',
#    'start': 57,
#    'end': 62},
#   {'entity_group': 'LOC',
#    'score': 0.9986486732959747,
#    'word': 'Golan',
#    'start': 129,
#    'end': 134}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.9995579123497009,
#    'word': 'Damascus',
#    'start': 27,
#    'end': 35}],
#  [],
#  [],
#  [{'entity_group': 'PER',
#    'score': 0.9994237422943115,
#    'word': 'Levy',
#    'start': 104,
#    'end': 108}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998446106910706,
#    'word': 'Syria',
#    'start': 17,
#    'end': 22},
#   {'entity_group': 'LOC',
#    'score': 0.9996850490570068,
#    'word': 'Israel',
#    'start': 71,
#    'end': 77}],
#  [{'entity_group': 'PER',
#    'score': 0.967975914478302,
#    'word': 'God',
#    'start': 23,
#    'end': 26}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.9997885823249817,
#    'word': 'Israel',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'ORG',
#    'score': 0.9977040588855743,
#    'word': 'Channel Two',
#    'start': 10,
#    'end': 21},
#   {'entity_group': 'LOC',
#    'score': 0.9996371269226074,
#    'word': 'Damascus',
#    'start': 38,
#    'end': 46},
#   {'entity_group': 'LOC',
#    'score': 0.9998147487640381,
#    'word': 'Israel',
#    'start': 80,
#    'end': 86}],
#  [],
#  [{'entity_group': 'PER',
#    'score': 0.9357670942942301,
#    'word': 'Netanyahu',
#    'start': 0,
#    'end': 9},
#   {'entity_group': 'PER',
#    'score': 0.9987115263938904,
#    'word': 'Levy',
#    'start': 14,
#    'end': 18}],
#  [{'entity_group': 'PER',
#    'score': 0.9520636200904846,
#    'word': 'Netanyahu',
#    'start': 30,
#    'end': 39},
#   {'entity_group': 'LOC',
#    'score': 0.9997481107711792,
#    'word': 'Syria',
#    'start': 70,
#    'end': 75},
#   {'entity_group': 'LOC',
#    'score': 0.9996637105941772,
#    'word': 'Cairo',
#    'start': 80,
#    'end': 85},
#   {'entity_group': 'LOC',
#    'score': 0.9997279644012451,
#    'word': 'United States',
#    'start': 92,
#    'end': 105},
#   {'entity_group': 'LOC',
#    'score': 0.999663770198822,
#    'word': 'Moscow',
#    'start': 110,
#    'end': 116}],
#  [{'entity_group': 'MISC',
#    'score': 0.9990072250366211,
#    'word': 'Polish',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'LOC',
#    'score': 0.9998553395271301,
#    'word': 'Libya',
#    'start': 42,
#    'end': 47}],
#  [{'entity_group': 'LOC',
#    'score': 0.9930740793546041,
#    'word': 'TUNIS',
#    'start': 0,
#    'end': 5}],
#  [{'entity_group': 'MISC',
#    'score': 0.9989907741546631,
#    'word': 'Polish',
#    'start': 2,
#    'end': 8},
#   {'entity_group': 'MISC',
#    'score': 0.9993097186088562,
#    'word': 'Polish',
#    'start': 39,
#    'end': 45},
#   {'entity_group': 'LOC',
#    'score': 0.9998539090156555,
#    'word': 'Libya',
#    'start': 76,
#    'end': 81},
#   {'entity_group': 'MISC',
#    'score': 0.9990664720535278,
#    'word': 'Polish',
#    'start': 113,
#    'end': 119},
#   {'entity_group': 'MISC',
#    'score': 0.9981699585914612,
#    'word': 'North African',
#    'start': 170,
#    'end': 183}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.9998784065246582,
#    'word': 'Libya',
#    'start': 68,
#    'end': 73},
#   {'entity_group': 'MISC',
#    'score': 0.9987890124320984,
#    'word': 'Polish',
#    'start': 140,
#    'end': 146},
#   {'entity_group': 'LOC',
#    'score': 0.9996712803840637,
#    'word': 'Tripoli',
#    'start': 179,
#    'end': 186},
#   {'entity_group': 'PER',
#    'score': 0.9946577027440071,
#    'word': 'Tadeusz Awdankiewicz',
#    'start': 189,
#    'end': 209},
#   {'entity_group': 'ORG',
#    'score': 0.9983013570308685,
#    'word': 'Reuters',
#    'start': 217,
#    'end': 224}],
#  [{'entity_group': 'LOC',
#    'score': 0.999835729598999,
#    'word': 'Poland',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'LOC',
#    'score': 0.9998880624771118,
#    'word': 'Libya',
#    'start': 65,
#    'end': 70},
#   {'entity_group': 'PER',
#    'score': 0.9753553986549377,
#    'word': 'Awdankiewicz',
#    'start': 92,
#    'end': 104}],
#  [{'entity_group': 'MISC',
#    'score': 0.9990519285202026,
#    'word': 'Polish',
#    'start': 40,
#    'end': 46},
#   {'entity_group': 'LOC',
#    'score': 0.9997984766960144,
#    'word': 'Libya',
#    'start': 65,
#    'end': 70}],
#  [{'entity_group': 'MISC',
#    'score': 0.9982156753540039,
#    'word': 'Iranian',
#    'start': 4,
#    'end': 11},
#   {'entity_group': 'LOC',
#    'score': 0.9997755289077759,
#    'word': 'Baghdad',
#    'start': 39,
#    'end': 46}],
#  [{'entity_group': 'PER',
#    'score': 0.9959657341241837,
#    'word': 'Hassan Hafidh',
#    'start': 0,
#    'end': 13}],
#  [{'entity_group': 'LOC',
#    'score': 0.998254582285881,
#    'word': 'BAGHDAD',
#    'start': 0,
#    'end': 7}],
#  [{'entity_group': 'MISC',
#    'score': 0.9971466660499573,
#    'word': 'Iranian',
#    'start': 3,
#    'end': 10},
#   {'entity_group': 'LOC',
#    'score': 0.9998857378959656,
#    'word': 'Iraq',
#    'start': 32,
#    'end': 36},
#   {'entity_group': 'LOC',
#    'score': 0.9998136758804321,
#    'word': 'Iran',
#    'start': 76,
#    'end': 80},
#   {'entity_group': 'MISC',
#    'score': 0.9954767227172852,
#    'word': 'Kurdish',
#    'start': 84,
#    'end': 91},
#   {'entity_group': 'MISC',
#    'score': 0.9980201125144958,
#    'word': 'Iranian',
#    'start': 127,
#    'end': 134},
#   {'entity_group': 'LOC',
#    'score': 0.9998602867126465,
#    'word': 'Iraq',
#    'start': 154,
#    'end': 158}],
#  [{'entity_group': 'ORG',
#    'score': 0.9990889600345066,
#    'word': 'Mujahideen Khalq',
#    'start': 2,
#    'end': 18},
#   {'entity_group': 'PER',
#    'score': 0.9878116250038147,
#    'word': 'Massoud Rajavi',
#    'start': 45,
#    'end': 59},
#   {'entity_group': 'LOC',
#    'score': 0.9998019337654114,
#    'word': 'Baghdad',
#    'start': 67,
#    'end': 74},
#   {'entity_group': 'ORG',
#    'score': 0.9912629842758178,
#    'word': 'Kurdistan Democratic Party of Iran',
#    'start': 104,
#    'end': 138},
#   {'entity_group': 'ORG',
#    'score': 0.9981765548388163,
#    'word': 'KDPI',
#    'start': 141,
#    'end': 145},
#   {'entity_group': 'PER',
#    'score': 0.9939156621694565,
#    'word': 'Hassan Rastegar',
#    'start': 148,
#    'end': 163},
#   {'entity_group': 'LOC',
#    'score': 0.999771237373352,
#    'word': 'Iran',
#    'start': 203,
#    'end': 207},
#   {'entity_group': 'MISC',
#    'score': 0.9784971177577972,
#    'word': 'Kurds',
#    'start': 217,
#    'end': 222}],
#  [{'entity_group': 'MISC',
#    'score': 0.7606810927391052,
#    'word': 'Rajavi',
#    'start': 2,
#    'end': 8},
#   {'entity_group': 'MISC',
#    'score': 0.9012753367424011,
#    'word': 'Iranian',
#    'start': 29,
#    'end': 36},
#   {'entity_group': 'ORG',
#    'score': 0.9959307312965393,
#    'word': 'Resistance',
#    'start': 37,
#    'end': 47},
#   {'entity_group': 'MISC',
#    'score': 0.9966402649879456,
#    'word': 'Kurdish',
#    'start': 96,
#    'end': 103},
#   {'entity_group': 'LOC',
#    'score': 0.9965530633926392,
#    'word': 'Iranian Kurdistan',
#    'start': 147,
#    'end': 164}],
#  [{'entity_group': 'ORG',
#    'score': 0.9991720574242728,
#    'word': 'Mujahideen Khalq',
#    'start': 88,
#    'end': 104},
#   {'entity_group': 'MISC',
#    'score': 0.9957191944122314,
#    'word': 'Iranian Kurdish',
#    'start': 113,
#    'end': 128}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997414350509644,
#    'word': 'Iran',
#    'start': 0,
#    'end': 4},
#   {'entity_group': 'LOC',
#    'score': 0.9997308254241943,
#    'word': 'Iraq',
#    'start': 43,
#    'end': 47},
#   {'entity_group': 'ORG',
#    'score': 0.9952669938405355,
#    'word': 'KDPI',
#    'start': 70,
#    'end': 74},
#   {'entity_group': 'MISC',
#    'score': 0.9952564239501953,
#    'word': 'Iraqi Kurdish',
#    'start': 95,
#    'end': 108},
#   {'entity_group': 'LOC',
#    'score': 0.9995744824409485,
#    'word': 'Baghdad',
#    'start': 156,
#    'end': 163}],
#  [{'entity_group': 'MISC',
#    'score': 0.9950358867645264,
#    'word': 'Iraqi Kurdish',
#    'start': 0,
#    'end': 13},
#   {'entity_group': 'LOC',
#    'score': 0.999808132648468,
#    'word': 'Iran',
#    'start': 30,
#    'end': 34},
#   {'entity_group': 'ORG',
#    'score': 0.9985118011633555,
#    'word': 'Iraqi Kurdish Patriotic Union of Kurdistan',
#    'start': 78,
#    'end': 120},
#   {'entity_group': 'ORG',
#    'score': 0.9987779855728149,
#    'word': 'PUK',
#    'start': 123,
#    'end': 126}],
#  [{'entity_group': 'ORG',
#    'score': 0.9978505770365397,
#    'word': 'PUK',
#    'start': 0,
#    'end': 3},
#   {'entity_group': 'LOC',
#    'score': 0.9997035264968872,
#    'word': 'Iraq',
#    'start': 8,
#    'end': 12},
#   {'entity_group': 'ORG',
#    'score': 0.9995311299959818,
#    'word': 'Kurdistan Democratic Party',
#    'start': 16,
#    'end': 42},
#   {'entity_group': 'ORG',
#    'score': 0.999528169631958,
#    'word': 'KDP',
#    'start': 45,
#    'end': 48},
#   {'entity_group': 'MISC',
#    'score': 0.9938733875751495,
#    'word': 'Iraqi Kurdish',
#    'start': 64,
#    'end': 77},
#   {'entity_group': 'LOC',
#    'score': 0.9991629123687744,
#    'word': 'Iraq',
#    'start': 107,
#    'end': 111},
#   {'entity_group': 'MISC',
#    'score': 0.995213508605957,
#    'word': 'Iraqi',
#    'start': 138,
#    'end': 143},
#   {'entity_group': 'LOC',
#    'score': 0.9998005628585815,
#    'word': 'Kuwait',
#    'start': 168,
#    'end': 174},
#   {'entity_group': 'MISC',
#    'score': 0.9930478930473328,
#    'word': 'Gulf War',
#    'start': 187,
#    'end': 195}],
#  [{'entity_group': 'MISC',
#    'score': 0.9981717467308044,
#    'word': 'U',
#    'start': 94,
#    'end': 95},
#   {'entity_group': 'MISC',
#    'score': 0.9942626059055328,
#    'word': 'S.',
#    'start': 96,
#    'end': 98}],
#  [{'entity_group': 'ORG',
#    'score': 0.9991156373705182,
#    'word': 'Mujahideen Khalq',
#    'start': 0,
#    'end': 16},
#   {'entity_group': 'MISC',
#    'score': 0.9980840682983398,
#    'word': 'Iranian',
#    'start': 22,
#    'end': 29},
#   {'entity_group': 'ORG',
#    'score': 0.9981073439121246,
#    'word': 'KDP',
#    'start': 60,
#    'end': 63},
#   {'entity_group': 'LOC',
#    'score': 0.9963053266207377,
#    'word': 'Qasri',
#    'start': 77,
#    'end': 82},
#   {'entity_group': 'LOC',
#    'score': 0.9945428520441055,
#    'word': 'Suleimaniya',
#    'start': 93,
#    'end': 104},
#   {'entity_group': 'MISC',
#    'score': 0.998767614364624,
#    'word': 'Iranian',
#    'start': 123,
#    'end': 130}],
#  [{'entity_group': 'MISC',
#    'score': 0.9900635480880737,
#    'word': 'Iraqi Kurds',
#    'start': 18,
#    'end': 29}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998252391815186,
#    'word': 'Iran',
#    'start': 5,
#    'end': 9},
#   {'entity_group': 'LOC',
#    'score': 0.9998634457588196,
#    'word': 'Turkey',
#    'start': 14,
#    'end': 20},
#   {'entity_group': 'LOC',
#    'score': 0.9997467398643494,
#    'word': 'Iraq',
#    'start': 71,
#    'end': 75},
#   {'entity_group': 'MISC',
#    'score': 0.9947932362556458,
#    'word': 'Kurdish',
#    'start': 100,
#    'end': 107}],
#  [{'entity_group': 'MISC',
#    'score': 0.9963809251785278,
#    'word': 'U',
#    'start': 2,
#    'end': 3},
#   {'entity_group': 'MISC',
#    'score': 0.8242636819680532,
#    'word': 'S. -',
#    'start': 4,
#    'end': 7},
#   {'entity_group': 'LOC',
#    'score': 0.999830961227417,
#    'word': 'Turkey',
#    'start': 33,
#    'end': 39},
#   {'entity_group': 'MISC',
#    'score': 0.9882410367329916,
#    'word': 'Iraqi Kurds',
#    'start': 49,
#    'end': 60},
#   {'entity_group': 'LOC',
#    'score': 0.99967360496521,
#    'word': 'Baghdad',
#    'start': 86,
#    'end': 93}],
#  [{'entity_group': 'MISC',
#    'score': 0.9987394213676453,
#    'word': 'Saudi',
#    'start': 0,
#    'end': 5}],
#  [{'entity_group': 'LOC',
#    'score': 0.9958354830741882,
#    'word': 'MANAMA',
#    'start': 0,
#    'end': 6}],
#  [{'entity_group': 'MISC',
#    'score': 0.9987920522689819,
#    'word': 'Saudi',
#    'start': 9,
#    'end': 14}],
#  [{'entity_group': 'MISC',
#    'score': 0.9990511536598206,
#    'word': 'Saudi',
#    'start': 27,
#    'end': 32}],
#  [],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.9353312253952026,
#    'word': 'One',
#    'start': 0,
#    'end': 3}],
#  [{'entity_group': 'MISC',
#    'score': 0.9194509387016296,
#    'word': 'One',
#    'start': 0,
#    'end': 3}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997555017471313,
#    'word': 'Israel',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'PER',
#    'score': 0.998555600643158,
#    'word': 'Arafat',
#    'start': 16,
#    'end': 22},
#   {'entity_group': 'LOC',
#    'score': 0.9997568726539612,
#    'word': 'West Bank',
#    'start': 36,
#    'end': 45}],
#  [{'entity_group': 'LOC',
#    'score': 0.9935106635093689,
#    'word': 'JERUSALEM',
#    'start': 0,
#    'end': 9}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997336268424988,
#    'word': 'Israel',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'MISC',
#    'score': 0.997839093208313,
#    'word': 'Palestinian',
#    'start': 12,
#    'end': 23},
#   {'entity_group': 'PER',
#    'score': 0.9977776765823364,
#    'word': 'Yasser Arafat',
#    'start': 34,
#    'end': 47},
#   {'entity_group': 'LOC',
#    'score': 0.9997308850288391,
#    'word': 'West Bank',
#    'start': 104,
#    'end': 113},
#   {'entity_group': 'MISC',
#    'score': 0.9987016916275024,
#    'word': 'Israeli',
#    'start': 131,
#    'end': 138},
#   {'entity_group': 'ORG',
#    'score': 0.9349927504857382,
#    'word': 'PLO',
#    'start': 139,
#    'end': 142},
#   {'entity_group': 'PER',
#    'score': 0.9846179485321045,
#    'word': 'Arafat',
#    'start': 155,
#    'end': 161}],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.9990906715393066,
#    'word': 'Israeli',
#    'start': 66,
#    'end': 73},
#   {'entity_group': 'LOC',
#    'score': 0.9997387826442719,
#    'word': 'West Bank',
#    'start': 134,
#    'end': 143},
#   {'entity_group': 'PER',
#    'score': 0.9942631622155508,
#    'word': 'Nabil Abu Rdainah',
#    'start': 162,
#    'end': 179},
#   {'entity_group': 'ORG',
#    'score': 0.9976292252540588,
#    'word': 'Reuters',
#    'start': 185,
#    'end': 192}],
#  [{'entity_group': 'PER',
#    'score': 0.9991671244303385,
#    'word': 'Arafat',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'MISC',
#    'score': 0.9989644289016724,
#    'word': 'Israeli',
#    'start': 41,
#    'end': 48},
#   {'entity_group': 'PER',
#    'score': 0.9989422112703323,
#    'word': 'Shimon Peres',
#    'start': 64,
#    'end': 76},
#   {'entity_group': 'LOC',
#    'score': 0.9991632997989655,
#    'word': 'West Bank',
#    'start': 84,
#    'end': 93},
#   {'entity_group': 'LOC',
#    'score': 0.9996049404144287,
#    'word': 'Ramallah',
#    'start': 102,
#    'end': 110},
#   {'entity_group': 'LOC',
#    'score': 0.9997236728668213,
#    'word': 'Gaza',
#    'start': 152,
#    'end': 156},
#   {'entity_group': 'LOC',
#    'score': 0.9997351169586182,
#    'word': 'Israel',
#    'start': 163,
#    'end': 169},
#   {'entity_group': 'MISC',
#    'score': 0.9977477192878723,
#    'word': 'Palestinian',
#    'start': 201,
#    'end': 212}],
#  [{'entity_group': 'MISC',
#    'score': 0.9972182512283325,
#    'word': 'Palestinian',
#    'start': 0,
#    'end': 11},
#   {'entity_group': 'PER',
#    'score': 0.9793457835912704,
#    'word': 'Benjamin Netanyahu',
#    'start': 56,
#    'end': 74},
#   {'entity_group': 'LOC',
#    'score': 0.9996647238731384,
#    'word': 'Ramallah',
#    'start': 97,
#    'end': 105},
#   {'entity_group': 'PER',
#    'score': 0.9976140856742859,
#    'word': 'Arafat',
#    'start': 125,
#    'end': 131}],
#  [{'entity_group': 'PER',
#    'score': 0.9829946160316467,
#    'word': 'Arafat',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'MISC',
#    'score': 0.9990345239639282,
#    'word': 'Israeli',
#    'start': 48,
#    'end': 55},
#   {'entity_group': 'ORG',
#    'score': 0.9976645509401957,
#    'word': 'PLO',
#    'start': 60,
#    'end': 63},
#   {'entity_group': 'LOC',
#    'score': 0.9938167333602905,
#    'word': 'Allenby Bridge',
#    'start': 105,
#    'end': 119},
#   {'entity_group': 'LOC',
#    'score': 0.9998204708099365,
#    'word': 'Jordan',
#    'start': 137,
#    'end': 143},
#   {'entity_group': 'LOC',
#    'score': 0.999782383441925,
#    'word': 'West Bank',
#    'start': 152,
#    'end': 161}],
#  [{'entity_group': 'PER',
#    'score': 0.9879200160503387,
#    'word': 'Abu Rdainah',
#    'start': 0,
#    'end': 11},
#   {'entity_group': 'PER',
#    'score': 0.9986986915270487,
#    'word': 'Arafat',
#    'start': 17,
#    'end': 23},
#   {'entity_group': 'LOC',
#    'score': 0.999736100435257,
#    'word': 'West Bank',
#    'start': 58,
#    'end': 67},
#   {'entity_group': 'LOC',
#    'score': 0.9997372627258301,
#    'word': 'Israel',
#    'start': 88,
#    'end': 94},
#   {'entity_group': 'LOC',
#    'score': 0.9997317790985107,
#    'word': 'Gaza',
#    'start': 146,
#    'end': 150}],
#  [{'entity_group': 'PER',
#    'score': 0.9984193642934164,
#    'word': 'Arafat',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'PER',
#    'score': 0.9953374564647675,
#    'word': 'Peres',
#    'start': 15,
#    'end': 20},
#   {'entity_group': 'LOC',
#    'score': 0.9997798800468445,
#    'word': 'Gaza',
#    'start': 24,
#    'end': 28}],
#  [{'entity_group': 'LOC',
#    'score': 0.9935106635093689,
#    'word': 'JERUSALEM',
#    'start': 0,
#    'end': 9}],
#  [{'entity_group': 'PER',
#    'score': 0.9994141340255738,
#    'word': 'Yasser Arafat',
#    'start': 0,
#    'end': 13},
#   {'entity_group': 'PER',
#    'score': 0.9988575726747513,
#    'word': 'Shimon Peres',
#    'start': 24,
#    'end': 36},
#   {'entity_group': 'LOC',
#    'score': 0.9997825026512146,
#    'word': 'Gaza',
#    'start': 40,
#    'end': 44},
#   {'entity_group': 'MISC',
#    'score': 0.9915503859519958,
#    'word': 'Palestinians',
#    'start': 63,
#    'end': 75},
#   {'entity_group': 'MISC',
#    'score': 0.9988603591918945,
#    'word': 'Israeli',
#    'start': 96,
#    'end': 103},
#   {'entity_group': 'MISC',
#    'score': 0.9983391165733337,
#    'word': 'Palestinian',
#    'start': 130,
#    'end': 141},
#   {'entity_group': 'LOC',
#    'score': 0.9997696876525879,
#    'word': 'West Bank',
#    'start': 168,
#    'end': 177}],
#  [{'entity_group': 'PER',
#    'score': 0.9969047605991364,
#    'word': 'Peres',
#    'start': 22,
#    'end': 27},
#   {'entity_group': 'PER',
#    'score': 0.9965664545694987,
#    'word': 'Arafat',
#    'start': 32,
#    'end': 38},
#   {'entity_group': 'LOC',
#    'score': 0.9950174391269684,
#    'word': 'Erez',
#    'start': 58,
#    'end': 62},
#   {'entity_group': 'LOC',
#    'score': 0.9997618198394775,
#    'word': 'Gaza',
#    'start': 77,
#    'end': 81},
#   {'entity_group': 'LOC',
#    'score': 0.999668687582016,
#    'word': 'Ramallah',
#    'start': 93,
#    'end': 101},
#   {'entity_group': 'PER',
#    'score': 0.9974367916584015,
#    'word': 'Peres',
#    'start': 117,
#    'end': 122}],
#  [{'entity_group': 'MISC',
#    'score': 0.9975993037223816,
#    'word': 'Palestinian',
#    'start': 0,
#    'end': 11},
#   {'entity_group': 'MISC',
#    'score': 0.9989081621170044,
#    'word': 'Israeli',
#    'start': 31,
#    'end': 38},
#   {'entity_group': 'PER',
#    'score': 0.9986724853515625,
#    'word': 'Arafat',
#    'start': 61,
#    'end': 67},
#   {'entity_group': 'LOC',
#    'score': 0.9998344779014587,
#    'word': 'Israel',
#    'start': 84,
#    'end': 90},
#   {'entity_group': 'MISC',
#    'score': 0.998384416103363,
#    'word': 'Palestinian',
#    'start': 96,
#    'end': 107},
#   {'entity_group': 'LOC',
#    'score': 0.9997580647468567,
#    'word': 'West Bank',
#    'start': 126,
#    'end': 135},
#   {'entity_group': 'PER',
#    'score': 0.9943538308143616,
#    'word': 'Peres',
#    'start': 174,
#    'end': 179}],
#  [{'entity_group': 'MISC',
#    'score': 0.9989838600158691,
#    'word': 'Israeli',
#    'start': 0,
#    'end': 7},
#   {'entity_group': 'PER',
#    'score': 0.9881264269351959,
#    'word': 'Benjamin Netanyahu',
#    'start': 23,
#    'end': 41},
#   {'entity_group': 'PER',
#    'score': 0.9982801079750061,
#    'word': 'Peres',
#    'start': 72,
#    'end': 77},
#   {'entity_group': 'ORG',
#    'score': 0.9308778643608093,
#    'word': 'Likud',
#    'start': 142,
#    'end': 147}],
#  [{'entity_group': 'MISC',
#    'score': 0.9986665844917297,
#    'word': 'Afghan',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'LOC',
#    'score': 0.9980419278144836,
#    'word': 'UAE',
#    'start': 7,
#    'end': 10},
#   {'entity_group': 'MISC',
#    'score': 0.9951684176921844,
#    'word': 'Taleban',
#    'start': 24,
#    'end': 31}],
#  [{'entity_group': 'PER',
#    'score': 0.9964360396067301,
#    'word': 'Hilary Gush',
#    'start': 0,
#    'end': 11}],
#  [{'entity_group': 'LOC',
#    'score': 0.9931845366954803,
#    'word': 'DUBAI',
#    'start': 0,
#    'end': 5}],
#  [{'entity_group': 'MISC',
#    'score': 0.9982210993766785,
#    'word': 'Afghan',
#    'start': 6,
#    'end': 12},
#   {'entity_group': 'LOC',
#    'score': 0.9997799595197042,
#    'word': 'United Arab Emirates',
#    'start': 35,
#    'end': 55},
#   {'entity_group': 'MISC',
#    'score': 0.9991953372955322,
#    'word': 'Russian',
#    'start': 69,
#    'end': 76},
#   {'entity_group': 'MISC',
#    'score': 0.9950875639915466,
#    'word': 'Taleban',
#    'start': 107,
#    'end': 114},
#   {'entity_group': 'LOC',
#    'score': 0.999824047088623,
#    'word': 'Afghanistan',
#    'start': 138,
#    'end': 149},
#   {'entity_group': 'MISC',
#    'score': 0.998491644859314,
#    'word': 'Afghan',
#    'start': 170,
#    'end': 176},
#   {'entity_group': 'LOC',
#    'score': 0.99967822432518,
#    'word': 'Abu Dhabi',
#    'start': 188,
#    'end': 197}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998418688774109,
#    'word': 'UAE',
#    'start': 38,
#    'end': 41}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997791051864624,
#    'word': 'Afghanistan',
#    'start': 16,
#    'end': 27}],
#  [],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.9926752050717672,
#    'word': 'Islamic Taleban',
#    'start': 10,
#    'end': 25},
#   {'entity_group': 'MISC',
#    'score': 0.9992877840995789,
#    'word': 'Russian',
#    'start': 59,
#    'end': 66},
#   {'entity_group': 'LOC',
#    'score': 0.9990353584289551,
#    'word': 'UAE',
#    'start': 90,
#    'end': 93},
#   {'entity_group': 'LOC',
#    'score': 0.9992202123006185,
#    'word': 'Sharjah',
#    'start': 100,
#    'end': 107},
#   {'entity_group': 'MISC',
#    'score': 0.9942653477191925,
#    'word': 'Taleban',
#    'start': 181,
#    'end': 188},
#   {'entity_group': 'LOC',
#    'score': 0.9984596570332845,
#    'word': 'Kandahar',
#    'start': 200,
#    'end': 208},
#   {'entity_group': 'LOC',
#    'score': 0.9996721744537354,
#    'word': 'Afghanistan',
#    'start': 221,
#    'end': 232}],
#  [{'entity_group': 'LOC',
#    'score': 0.9996535181999207,
#    'word': 'UAE',
#    'start': 4,
#    'end': 7},
#   {'entity_group': 'ORG',
#    'score': 0.9991501172383627,
#    'word': 'International Red Crescent',
#    'start': 59,
#    'end': 85}],
#  [],
#  [{'entity_group': 'LOC',
#    'score': 0.9982670744260153,
#    'word': 'Kandahar',
#    'start': 57,
#    'end': 65},
#   {'entity_group': 'MISC',
#    'score': 0.9983876943588257,
#    'word': 'Afghan',
#    'start': 73,
#    'end': 79},
#   {'entity_group': 'LOC',
#    'score': 0.999660313129425,
#    'word': 'Kabul',
#    'start': 88,
#    'end': 93},
#   {'entity_group': 'LOC',
#    'score': 0.9988281528155009,
#    'word': 'Kandahar',
#    'start': 167,
#    'end': 175}],
#  [{'entity_group': 'LOC',
#    'score': 0.9980707168579102,
#    'word': 'Kandahar',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'MISC',
#    'score': 0.994253933429718,
#    'word': 'Taleban',
#    'start': 47,
#    'end': 54}],
#  [{'entity_group': 'LOC',
#    'score': 0.9994838833808899,
#    'word': 'Kabul',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'PER',
#    'score': 0.9874765362058368,
#    'word': 'Burhanuddin Rabbani',
#    'start': 33,
#    'end': 52},
#   {'entity_group': 'MISC',
#    'score': 0.9909875988960266,
#    'word': 'Taleban',
#    'start': 75,
#    'end': 82}],
#  [{'entity_group': 'LOC',
#    'score': 0.9996843039989471,
#    'word': 'Abu Dhabi',
#    'start': 90,
#    'end': 99}],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.9983304142951965,
#    'word': 'Russians',
#    'start': 4,
#    'end': 12},
#   {'entity_group': 'ORG',
#    'score': 0.9969775974750519,
#    'word': 'Aerostan',
#    'start': 31,
#    'end': 39},
#   {'entity_group': 'MISC',
#    'score': 0.9986969828605652,
#    'word': 'Russian',
#    'start': 52,
#    'end': 59},
#   {'entity_group': 'LOC',
#    'score': 0.9992358088493347,
#    'word': 'Tatarstan',
#    'start': 72,
#    'end': 81},
#   {'entity_group': 'MISC',
#    'score': 0.9947318434715271,
#    'word': 'Taleban',
#    'start': 111,
#    'end': 118},
#   {'entity_group': 'MISC',
#    'score': 0.7167410453160604,
#    'word': 'MiG - 19',
#    'start': 119,
#    'end': 125}],
#  [{'entity_group': 'MISC',
#    'score': 0.9916900098323822,
#    'word': 'Taleban',
#    'start': 0,
#    'end': 7},
#   {'entity_group': 'LOC',
#    'score': 0.9998357892036438,
#    'word': 'Albania',
#    'start': 45,
#    'end': 52},
#   {'entity_group': 'MISC',
#    'score': 0.9990836977958679,
#    'word': 'Russian',
#    'start': 69,
#    'end': 76},
#   {'entity_group': 'PER',
#    'score': 0.9813787341117859,
#    'word': 'Rabbani',
#    'start': 98,
#    'end': 105}],
#  [{'entity_group': 'LOC',
#    'score': 0.9993862509727478,
#    'word': 'Moscow',
#    'start': 0,
#    'end': 6}],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.998583972454071,
#    'word': 'Russians',
#    'start': 4,
#    'end': 12},
#   {'entity_group': 'MISC',
#    'score': 0.9628904064496359,
#    'word': 'Kalashnikov',
#    'start': 70,
#    'end': 81},
#   {'entity_group': 'MISC',
#    'score': 0.9915842711925507,
#    'word': 'Ilyushin 76',
#    'start': 148,
# ...
#    'score': 0.9998234808444977,
#    'word': 'New Zealand',
#    'start': 41,
#    'end': 52},
#   {'entity_group': 'PER',
#    'score': 0.999755859375,
#    'word': 'Ian',
#    'start': 57,
#    'end': 60}],
#  [{'entity_group': 'PER',
#    'score': 0.9919472535451254,
#    'word': 'Woosnam',
#    'start': 0,
#    'end': 7},
#   {'entity_group': 'PER',
#    'score': 0.999467929204305,
#    'word': 'Bernhard Langer',
#    'start': 10,
#    'end': 25},
#   {'entity_group': 'LOC',
#    'score': 0.999865710735321,
#    'word': 'Germany',
#    'start': 28,
#    'end': 35},
#   {'entity_group': 'PER',
#    'score': 0.9978993088006973,
#    'word': 'Ronan Rafferty',
#    'start': 40,
#    'end': 54},
#   {'entity_group': 'PER',
#    'score': 0.9992411732673645,
#    'word': 'Mats',
#    'start': 57,
#    'end': 61}],
#  [{'entity_group': 'PER',
#    'score': 0.9993614852428436,
#    'word': 'Lanner',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'LOC',
#    'score': 0.9998743534088135,
#    'word': 'Sweden',
#    'start': 9,
#    'end': 15},
#   {'entity_group': 'PER',
#    'score': 0.9997744858264923,
#    'word': 'Wayne Riley',
#    'start': 20,
#    'end': 31},
#   {'entity_group': 'LOC',
#    'score': 0.9998472929000854,
#    'word': 'Australia',
#    'start': 34,
#    'end': 43}],
#  [{'entity_group': 'PER',
#    'score': 0.999780610203743,
#    'word': 'Eamonn Darcy',
#    'start': 3,
#    'end': 15},
#   {'entity_group': 'LOC',
#    'score': 0.9998663067817688,
#    'word': 'Ireland',
#    'start': 18,
#    'end': 25},
#   {'entity_group': 'PER',
#    'score': 0.9997698068618774,
#    'word': 'Per Nyman',
#    'start': 30,
#    'end': 39},
#   {'entity_group': 'LOC',
#    'score': 0.9998961687088013,
#    'word': 'Sweden',
#    'start': 42,
#    'end': 48},
#   {'entity_group': 'PER',
#    'score': 0.9995445807774862,
#    'word': 'Russell Claydon',
#    'start': 53,
#    'end': 68}],
#  [{'entity_group': 'PER',
#    'score': 0.9997835755348206,
#    'word': 'Mark Roe',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'PER',
#    'score': 0.9996399760246277,
#    'word': 'Retief Goosen',
#    'start': 11,
#    'end': 24},
#   {'entity_group': 'LOC',
#    'score': 0.9998272359371185,
#    'word': 'South Africa',
#    'start': 27,
#    'end': 39},
#   {'entity_group': 'PER',
#    'score': 0.9990748763084412,
#    'word': 'Carl Suneson',
#    'start': 44,
#    'end': 56}],
#  [{'entity_group': 'PER',
#    'score': 0.9997556209564209,
#    'word': 'Stephen Field',
#    'start': 3,
#    'end': 16},
#   {'entity_group': 'PER',
#    'score': 0.9996984601020813,
#    'word': 'Paul Lawrie',
#    'start': 19,
#    'end': 30},
#   {'entity_group': 'PER',
#    'score': 0.9997613430023193,
#    'word': 'Ian Pyman',
#    'start': 33,
#    'end': 42},
#   {'entity_group': 'PER',
#    'score': 0.9554634094238281,
#    'word': 'Max Anglert',
#    'start': 45,
#    'end': 56}],
#  [{'entity_group': 'LOC',
#    'score': 0.999869704246521,
#    'word': 'Sweden',
#    'start': 2,
#    'end': 8},
#   {'entity_group': 'PER',
#    'score': 0.9725208163261414,
#    'word': 'Miles Tunnicliff',
#    'start': 13,
#    'end': 29},
#   {'entity_group': 'PER',
#    'score': 0.9957426488399506,
#    'word': 'Christian Cevaer',
#    'start': 32,
#    'end': 48},
#   {'entity_group': 'LOC',
#    'score': 0.9998834729194641,
#    'word': 'France',
#    'start': 51,
#    'end': 57}],
#  [{'entity_group': 'PER',
#    'score': 0.9983174204826355,
#    'word': 'Des Smyth',
#    'start': 0,
#    'end': 9},
#   {'entity_group': 'LOC',
#    'score': 0.9998531341552734,
#    'word': 'Ireland',
#    'start': 12,
#    'end': 19},
#   {'entity_group': 'PER',
#    'score': 0.9998010098934174,
#    'word': 'David Carter',
#    'start': 24,
#    'end': 36},
#   {'entity_group': 'PER',
#    'score': 0.9997777342796326,
#    'word': 'Lee Westwood',
#    'start': 39,
#    'end': 51},
#   {'entity_group': 'PER',
#    'score': 0.999708354473114,
#    'word': 'Greg',
#    'start': 54,
#    'end': 58}],
#  [{'entity_group': 'PER',
#    'score': 0.9990137020746866,
#    'word': 'Chalmers',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'LOC',
#    'score': 0.9998528361320496,
#    'word': 'Australia',
#    'start': 11,
#    'end': 20},
#   {'entity_group': 'PER',
#    'score': 0.9996692935625712,
#    'word': 'Miguel Angel Martin',
#    'start': 25,
#    'end': 44},
#   {'entity_group': 'LOC',
#    'score': 0.9998946785926819,
#    'word': 'Spain',
#    'start': 47,
#    'end': 52}],
#  [{'entity_group': 'PER',
#    'score': 0.9992157518863678,
#    'word': 'Thomas Bjorn',
#    'start': 0,
#    'end': 12},
#   {'entity_group': 'LOC',
#    'score': 0.9998626112937927,
#    'word': 'Denmark',
#    'start': 15,
#    'end': 22},
#   {'entity_group': 'PER',
#    'score': 0.9974756240844727,
#    'word': 'Fernando Roca',
#    'start': 27,
#    'end': 40},
#   {'entity_group': 'LOC',
#    'score': 0.9998911023139954,
#    'word': 'Spain',
#    'start': 43,
#    'end': 48},
#   {'entity_group': 'PER',
#    'score': 0.999768853187561,
#    'word': 'Derrick',
#    'start': 53,
#    'end': 60}],
#  [{'entity_group': 'PER',
#    'score': 0.993399441242218,
#    'word': 'Cooper',
#    'start': 0,
#    'end': 6}],
#  [{'entity_group': 'PER',
#    'score': 0.9987249573071798,
#    'word': 'Jeff Hawksworth',
#    'start': 3,
#    'end': 18},
#   {'entity_group': 'PER',
#    'score': 0.9996351897716522,
#    'word': 'Padraig Harrington',
#    'start': 21,
#    'end': 39},
#   {'entity_group': 'LOC',
#    'score': 0.9998754262924194,
#    'word': 'Ireland',
#    'start': 42,
#    'end': 49},
#   {'entity_group': 'PER',
#    'score': 0.9997462630271912,
#    'word': 'Michael',
#    'start': 54,
#    'end': 61}],
#  [{'entity_group': 'PER',
#    'score': 0.9995789527893066,
#    'word': 'Welch',
#    'start': 0,
#    'end': 5},
#   {'entity_group': 'PER',
#    'score': 0.9980592280626297,
#    'word': 'Thomas Gogele',
#    'start': 8,
#    'end': 21},
#   {'entity_group': 'LOC',
#    'score': 0.9998681545257568,
#    'word': 'Germany',
#    'start': 24,
#    'end': 31},
#   {'entity_group': 'PER',
#    'score': 0.995538741350174,
#    'word': 'Paul McGinley',
#    'start': 36,
#    'end': 49},
#   {'entity_group': 'LOC',
#    'score': 0.9998745918273926,
#    'word': 'Ireland',
#    'start': 52,
#    'end': 59}],
#  [{'entity_group': 'PER',
#    'score': 0.999244769414266,
#    'word': 'Gary Orr',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'PER',
#    'score': 0.9964826703071594,
#    'word': 'Jose - Maria Canizares',
#    'start': 11,
#    'end': 31},
#   {'entity_group': 'LOC',
#    'score': 0.9998679757118225,
#    'word': 'Spain',
#    'start': 34,
#    'end': 39},
#   {'entity_group': 'PER',
#    'score': 0.9995447595914205,
#    'word': 'Michael Jonzon',
#    'start': 44,
#    'end': 58}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998617172241211,
#    'word': 'Sweden',
#    'start': 2,
#    'end': 8},
#   {'entity_group': 'PER',
#    'score': 0.9992743333180746,
#    'word': 'Paul Eales',
#    'start': 13,
#    'end': 23},
#   {'entity_group': 'PER',
#    'score': 0.9996848404407501,
#    'word': 'David Williams',
#    'start': 26,
#    'end': 40},
#   {'entity_group': 'PER',
#    'score': 0.998855988184611,
#    'word': 'Andrew Coltart',
#    'start': 43,
#    'end': 57}],
#  [{'entity_group': 'PER',
#    'score': 0.9992818236351013,
#    'word': 'Jonathan Lomas',
#    'start': 0,
#    'end': 14},
#   {'entity_group': 'PER',
#    'score': 0.99941486120224,
#    'word': 'Jose Rivero',
#    'start': 17,
#    'end': 28},
#   {'entity_group': 'LOC',
#    'score': 0.9998830556869507,
#    'word': 'Spain',
#    'start': 31,
#    'end': 36},
#   {'entity_group': 'PER',
#    'score': 0.9995523691177368,
#    'word': 'Robert Karlsson',
#    'start': 41,
#    'end': 56}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998809695243835,
#    'word': 'Sweden',
#    'start': 2,
#    'end': 8},
#   {'entity_group': 'PER',
#    'score': 0.9997605681419373,
#    'word': 'Marcus Wills',
#    'start': 13,
#    'end': 25},
#   {'entity_group': 'PER',
#    'score': 0.999782939751943,
#    'word': 'Pedro Linhart',
#    'start': 28,
#    'end': 41},
#   {'entity_group': 'LOC',
#    'score': 0.9998926520347595,
#    'word': 'Spain',
#    'start': 44,
#    'end': 49},
#   {'entity_group': 'PER',
#    'score': 0.9997404217720032,
#    'word': 'Jamie',
#    'start': 54,
#    'end': 59}],
#  [{'entity_group': 'PER',
#    'score': 0.9997346997261047,
#    'word': 'Spence',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'PER',
#    'score': 0.9997901022434235,
#    'word': 'Terry Price',
#    'start': 9,
#    'end': 20},
#   {'entity_group': 'LOC',
#    'score': 0.9998530149459839,
#    'word': 'Australia',
#    'start': 23,
#    'end': 32},
#   {'entity_group': 'PER',
#    'score': 0.9994552731513977,
#    'word': 'Juan Carlos Pinero',
#    'start': 37,
#    'end': 55},
#   {'entity_group': 'LOC',
#    'score': 0.9998950362205505,
#    'word': 'Spain',
#    'start': 58,
#    'end': 63}],
#  [{'entity_group': 'PER',
#    'score': 0.9697831273078918,
#    'word': 'Mark Mouland',
#    'start': 0,
#    'end': 12}],
#  [{'entity_group': 'ORG',
#    'score': 0.9942805767059326,
#    'word': 'UEFA',
#    'start': 9,
#    'end': 13}],
#  [{'entity_group': 'LOC',
#    'score': 0.9972087740898132,
#    'word': 'GENEVA',
#    'start': 0,
#    'end': 6}],
#  [{'entity_group': 'LOC',
#    'score': 0.999809980392456,
#    'word': 'Norway',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'LOC',
#    'score': 0.9998023509979248,
#    'word': 'England',
#    'start': 9,
#    'end': 16},
#   {'entity_group': 'LOC',
#    'score': 0.9998360276222229,
#    'word': 'Sweden',
#    'start': 21,
#    'end': 27},
#   {'entity_group': 'MISC',
#    'score': 0.9967721998691559,
#    'word': 'UEFA Cup',
#    'start': 114,
#    'end': 122}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998025894165039,
#    'word': 'Norway',
#    'start': 0,
#    'end': 6},
#   {'entity_group': 'MISC',
#    'score': 0.9969337979952494,
#    'word': 'UEFA Fair Play',
#    'start': 18,
#    'end': 32},
#   {'entity_group': 'LOC',
#    'score': 0.9997699856758118,
#    'word': 'England',
#    'start': 82,
#    'end': 89},
#   {'entity_group': 'LOC',
#    'score': 0.9997906684875488,
#    'word': 'Sweden',
#    'start': 104,
#    'end': 110}],
#  [],
#  [],
#  [{'entity_group': 'MISC',
#    'score': 0.9970505634943644,
#    'word': 'UEFA Fair Play',
#    'start': 4,
#    'end': 18}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997608661651611,
#    'word': 'Norway',
#    'start': 0,
#    'end': 6}],
#  [{'entity_group': 'LOC',
#    'score': 0.999730110168457,
#    'word': 'England',
#    'start': 3,
#    'end': 10}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997884631156921,
#    'word': 'Sweden',
#    'start': 3,
#    'end': 9}],
#  [{'entity_group': 'LOC',
#    'score': 0.9992126027743021,
#    'word': 'Faroe Islands',
#    'start': 3,
#    'end': 16}],
#  [{'entity_group': 'LOC',
#    'score': 0.9996991157531738,
#    'word': 'Wales',
#    'start': 3,
#    'end': 8}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997329115867615,
#    'word': 'Estonia',
#    'start': 3,
#    'end': 10}],
#  [{'entity_group': 'LOC',
#    'score': 0.9996837377548218,
#    'word': 'Ireland',
#    'start': 3,
#    'end': 10}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997545480728149,
#    'word': 'Belarus',
#    'start': 3,
#    'end': 10}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997431635856628,
#    'word': 'Iceland',
#    'start': 3,
#    'end': 10}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998096227645874,
#    'word': 'Netherlands',
#    'start': 4,
#    'end': 15}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998145699501038,
#    'word': 'Denmark',
#    'start': 4,
#    'end': 11}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997667074203491,
#    'word': 'Germany',
#    'start': 4,
#    'end': 11}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997439384460449,
#    'word': 'Scotland',
#    'start': 4,
#    'end': 12}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997713565826416,
#    'word': 'Latvia',
#    'start': 4,
#    'end': 10}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997831583023071,
#    'word': 'Moldova',
#    'start': 4,
#    'end': 11}],
#  [{'entity_group': 'LOC',
#    'score': 0.999767005443573,
#    'word': 'Yugoslavia',
#    'start': 4,
#    'end': 14}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997493028640747,
#    'word': 'Belgium',
#    'start': 4,
#    'end': 11}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997458457946777,
#    'word': 'Luxembourg',
#    'start': 4,
#    'end': 14}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997631907463074,
#    'word': 'France',
#    'start': 4,
#    'end': 10}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997657537460327,
#    'word': 'Israel',
#    'start': 4,
#    'end': 10}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997609853744507,
#    'word': 'Switzerland',
#    'start': 4,
#    'end': 15}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997900724411011,
#    'word': 'Slovakia',
#    'start': 4,
#    'end': 12}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997789263725281,
#    'word': 'Poland',
#    'start': 4,
#    'end': 10}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998118877410889,
#    'word': 'Portugal',
#    'start': 4,
#    'end': 12}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997264742851257,
#    'word': 'Georgia',
#    'start': 4,
#    'end': 11}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997535347938538,
#    'word': 'Ukraine',
#    'start': 4,
#    'end': 11}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997907280921936,
#    'word': 'Spain',
#    'start': 4,
#    'end': 9}],
#  [{'entity_group': 'LOC',
#    'score': 0.999780535697937,
#    'word': 'Finland',
#    'start': 4,
#    'end': 11}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997574090957642,
#    'word': 'Macedonia',
#    'start': 4,
#    'end': 13}],
#  [{'entity_group': 'LOC',
#    'score': 0.9998071193695068,
#    'word': 'Lithuania',
#    'start': 4,
#    'end': 13}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997158646583557,
#    'word': 'Austria',
#    'start': 4,
#    'end': 11}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997839331626892,
#    'word': 'Russia',
#    'start': 4,
#    'end': 10}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997647404670715,
#    'word': 'Romania',
#    'start': 4,
#    'end': 11}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997901916503906,
#    'word': 'Turkey',
#    'start': 4,
#    'end': 10}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997922778129578,
#    'word': 'Hungary',
#    'start': 4,
#    'end': 11}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997754096984863,
#    'word': 'Czech Republic',
#    'start': 4,
#    'end': 18}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997884631156921,
#    'word': 'Greece',
#    'start': 4,
#    'end': 10}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997450113296509,
#    'word': 'Northern Ireland',
#    'start': 4,
#    'end': 20}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997804760932922,
#    'word': 'Italy',
#    'start': 4,
#    'end': 9}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997441172599792,
#    'word': 'Cyprus',
#    'start': 4,
#    'end': 10}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997178316116333,
#    'word': 'Armenia',
#    'start': 4,
#    'end': 11}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997695684432983,
#    'word': 'Slovenia',
#    'start': 4,
#    'end': 12}],
#  [{'entity_group': 'LOC',
#    'score': 0.999767541885376,
#    'word': 'Croatia',
#    'start': 4,
#    'end': 11}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997600317001343,
#    'word': 'Bulgaria',
#    'start': 4,
#    'end': 12}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997423887252808,
#    'word': 'Malta',
#    'start': 4,
#    'end': 9}],
#  [{'entity_group': 'MISC',
#    'score': 0.951876680056254,
#    'word': 'AUSTRALIANS',
#    'start': 39,
#    'end': 50}],
#  [{'entity_group': 'LOC',
#    'score': 0.9939241111278534,
#    'word': 'COLOMBO',
#    'start': 0,
#    'end': 7}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997391104698181,
#    'word': 'Australia',
#    'start': 49,
#    'end': 58},
#   {'entity_group': 'LOC',
#    'score': 0.9998109340667725,
#    'word': 'Sri Lanka',
#    'start': 86,
#    'end': 95}],
#  [{'entity_group': 'LOC',
#    'score': 0.9997532367706299,
#    'word': 'Australia',
#    'start': 0,
#    'end': 9},
#   {'entity_group': 'LOC',
#    'score': 0.999744176864624,
#    'word': 'Sri Lanka',
#    'start': 15,
#    'end': 24},
#   {'entity_group': 'LOC',
#    'score': 0.9998572468757629,
#    'word': 'India',
#    'start': 76,
#    'end': 81},
#   {'entity_group': 'LOC',
#    'score': 0.9998865127563477,
#    'word': 'Zimbabwe',
#    'start': 86,
#    'end': 94}],
#  [{'entity_group': 'MISC',
#    'score': 0.9956427812576294,
#    'word': 'World Cup',
#    'start': 67,
#    'end': 76}],
#  [{'entity_group': 'LOC',
#    'score': 0.999753475189209,
#    'word': 'Australia',
#    'start': 0,
#    'end': 9}],
#  [{'entity_group': 'PER',
#    'score': 0.9991108973821005,
#    'word': 'Ricky Ponting',
#    'start': 0,
#    'end': 13}],
#  [],
#  ...]
